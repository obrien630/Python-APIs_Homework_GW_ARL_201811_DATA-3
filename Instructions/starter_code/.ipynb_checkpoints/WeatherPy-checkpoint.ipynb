# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
now = datetime.datetime.now()

#Specifying output file in which to store cities
response_json = []

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Creating base URL and empty dataframe
url = f'https://api.openweathermap.org/data/2.5/weather?APPID={api_key}&units=imperial&q='
data_df = pd.DataFrame({'City':[],
                        'Cloudiness':[],
                        'Country':[],
                        'Date':[],
                        'Humidity':[],
                        'Lat':[],
                        'Lng':[],
                        'Max_temp':[],
                        'Wind_speed':[]
                       })

#API request for each city and populating dataframe in the same loop
i = 0
for city in cities:    
    response_req = requests.get(url+city)
    response = response_req.json()

    if (response['cod'] == 200):
        i = i+1
        print(f'Processing Record {i} | {city}')
        print(response_req.url)

        data_df.loc[i,'City'] = city
        data_df.loc[i,'Cloudiness'] = response['clouds']['all']
        data_df.loc[i,'Country'] = response['sys']['country']
        data_df.loc[i,'Date'] = now.strftime("%Y-%m-%d") 
        data_df.loc[i,'Humidity'] = response['main']['humidity']
        data_df.loc[i,'Lat'] = response['coord']['lat']
        data_df.loc[i,'Lng'] = response['coord']['lon']
        data_df.loc[i,'Max_temp'] = response['main']['temp_max']
        data_df.loc[i,'Wind_speed'] = response['wind']['speed']
    else:
        print('City not found. Skipping')
            
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Processing Record 1 | bluff
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bluff
# Processing Record 2 | victoria
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=victoria
# Processing Record 3 | wattegama
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=wattegama
# Processing Record 4 | vaini
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=vaini
# Processing Record 5 | souris
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=souris
# Processing Record 6 | ushuaia
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ushuaia
# Processing Record 7 | shache
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=shache
# Processing Record 8 | pontianak
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pontianak
# Processing Record 9 | taoudenni
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=taoudenni
# Processing Record 10 | bilma
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bilma
# Processing Record 11 | atuona
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=atuona
# City not found. Skipping
# Processing Record 12 | hermanus
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hermanus
# Processing Record 13 | jamestown
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=jamestown
# Processing Record 14 | dikson
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dikson
# Processing Record 15 | tevaitoa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tevaitoa
# Processing Record 16 | bethel
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bethel
# Processing Record 17 | mar del plata
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mar%20del%20plata
# Processing Record 18 | karratha
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=karratha
# Processing Record 19 | kamloops
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kamloops
# City not found. Skipping
# Processing Record 20 | georgetown
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=georgetown
# Processing Record 21 | alibag
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=alibag
# Processing Record 22 | dalby
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dalby
# Processing Record 23 | rikitea
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rikitea
# Processing Record 24 | new norfolk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=new%20norfolk
# Processing Record 25 | najran
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=najran
# Processing Record 26 | port alfred
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=port%20alfred
# Processing Record 27 | pec
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pec
# Processing Record 28 | hobart
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hobart
# Processing Record 29 | morgan city
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=morgan%20city
# Processing Record 30 | hithadhoo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hithadhoo
# Processing Record 31 | lebu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=lebu
# Processing Record 32 | lagoa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=lagoa
# Processing Record 33 | fort nelson
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=fort%20nelson
# Processing Record 34 | comodoro rivadavia
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=comodoro%20rivadavia
# City not found. Skipping
# Processing Record 35 | gat
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=gat
# City not found. Skipping
# Processing Record 36 | xuddur
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=xuddur
# City not found. Skipping
# Processing Record 37 | pisco
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pisco
# Processing Record 38 | mataura
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mataura
# Processing Record 39 | hilo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hilo
# Processing Record 40 | saint-georges
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=saint-georges
# Processing Record 41 | busselton
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=busselton
# Processing Record 42 | telimele
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=telimele
# Processing Record 43 | mayo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mayo
# Processing Record 44 | praia da vitoria
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=praia%20da%20vitoria
# Processing Record 45 | bredasdorp
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bredasdorp
# Processing Record 46 | benguela
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=benguela
# Processing Record 47 | sarahan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sarahan
# Processing Record 48 | bose
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bose
# Processing Record 49 | port elizabeth
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=port%20elizabeth
# Processing Record 50 | chuy
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=chuy
# City not found. Skipping
# Processing Record 51 | goderich
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=goderich
# Processing Record 52 | shubarshi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=shubarshi
# City not found. Skipping
# Processing Record 53 | dwarka
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dwarka
# Processing Record 54 | stavern
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=stavern
# Processing Record 55 | souillac
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=souillac
# Processing Record 56 | xichang
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=xichang
# Processing Record 57 | soyo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=soyo
# City not found. Skipping
# Processing Record 58 | smithers
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=smithers
# Processing Record 59 | tsiroanomandidy
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tsiroanomandidy
# Processing Record 60 | leh
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=leh
# Processing Record 61 | baykalsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=baykalsk
# Processing Record 62 | nioro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nioro
# Processing Record 63 | khatanga
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=khatanga
# Processing Record 64 | rosita
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rosita
# Processing Record 65 | saskylakh
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=saskylakh
# Processing Record 66 | springdale
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=springdale
# Processing Record 67 | albany
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=albany
# Processing Record 68 | barrow
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=barrow
# Processing Record 69 | elmadag
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=elmadag
# Processing Record 70 | nikolskoye
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nikolskoye
# Processing Record 71 | tessalit
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tessalit
# Processing Record 72 | yellowknife
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=yellowknife
# Processing Record 73 | cidreira
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cidreira
# Processing Record 74 | innisfail
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=innisfail
# Processing Record 75 | lavrentiya
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=lavrentiya
# Processing Record 76 | egyek
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=egyek
# Processing Record 77 | mokolo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mokolo
# Processing Record 78 | pangnirtung
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pangnirtung
# Processing Record 79 | riberalta
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=riberalta
# Processing Record 80 | butaritari
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=butaritari
# Processing Record 81 | roblin
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=roblin
# Processing Record 82 | marzuq
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=marzuq
# City not found. Skipping
# Processing Record 83 | kapaa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kapaa
# City not found. Skipping
# City not found. Skipping
# Processing Record 84 | richards bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=richards%20bay
# Processing Record 85 | airai
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=airai
# City not found. Skipping
# Processing Record 86 | bulgan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bulgan
# City not found. Skipping
# Processing Record 87 | dicabisagan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dicabisagan
# Processing Record 88 | datong
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=datong
# City not found. Skipping
# Processing Record 89 | townsville
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=townsville
# Processing Record 90 | ribeira grande
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ribeira%20grande
# Processing Record 91 | santa vitoria
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=santa%20vitoria
# Processing Record 92 | faanui
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=faanui
# Processing Record 93 | bonavista
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bonavista
# Processing Record 94 | malabo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=malabo
# Processing Record 95 | apomu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=apomu
# Processing Record 96 | muisne
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=muisne
# Processing Record 97 | bambous virieux
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bambous%20virieux
# Processing Record 98 | birao
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=birao
# Processing Record 99 | jiaocheng
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=jiaocheng
# Processing Record 100 | ranong
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ranong
# Processing Record 101 | bathsheba
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bathsheba
# Processing Record 102 | lasa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=lasa
# Processing Record 103 | ratanpur
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ratanpur
# Processing Record 104 | beira
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=beira
# Processing Record 105 | balangir
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=balangir
# Processing Record 106 | boueni
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=boueni
# City not found. Skipping
# Processing Record 107 | agirish
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=agirish
# Processing Record 108 | pauini
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pauini
# Processing Record 109 | bogotol
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bogotol
# Processing Record 110 | cabo san lucas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cabo%20san%20lucas
# Processing Record 111 | puerto ayora
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=puerto%20ayora
# Processing Record 112 | takaka
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=takaka
# Processing Record 113 | nyimba
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nyimba
# Processing Record 114 | codrington
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=codrington
# Processing Record 115 | cartagena del chaira
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cartagena%20del%20chaira
# Processing Record 116 | punta arenas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=punta%20arenas
# City not found. Skipping
# Processing Record 117 | fonte boa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=fonte%20boa
# Processing Record 118 | puro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=puro
# Processing Record 119 | dunedin
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dunedin
# Processing Record 120 | kruisfontein
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kruisfontein
# City not found. Skipping
# Processing Record 121 | longyearbyen
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=longyearbyen
# Processing Record 122 | nanortalik
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nanortalik
# Processing Record 123 | wewak
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=wewak
# Processing Record 124 | puerto escondido
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=puerto%20escondido
# Processing Record 125 | marabba
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=marabba
# Processing Record 126 | moranbah
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=moranbah
# Processing Record 127 | saint george
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=saint%20george
# Processing Record 128 | qaanaaq
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=qaanaaq
# Processing Record 129 | romny
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=romny
# City not found. Skipping
# Processing Record 130 | iqaluit
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=iqaluit
# Processing Record 131 | motihari
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=motihari
# Processing Record 132 | zhob
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=zhob
# Processing Record 133 | arraial do cabo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=arraial%20do%20cabo
# Processing Record 134 | mount gambier
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mount%20gambier
# Processing Record 135 | jeremie
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=jeremie
# Processing Record 136 | vao
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=vao
# City not found. Skipping
# Processing Record 137 | harper
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=harper
# Processing Record 138 | vanavara
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=vanavara
# City not found. Skipping
# Processing Record 139 | simga
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=simga
# Processing Record 140 | port blair
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=port%20blair
# Processing Record 141 | avarua
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=avarua
# City not found. Skipping
# Processing Record 142 | soma
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=soma
# City not found. Skipping
# Processing Record 143 | bystryy istok
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bystryy%20istok
# Processing Record 144 | ambilobe
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ambilobe
# Processing Record 145 | goundi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=goundi
# Processing Record 146 | gamba
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=gamba
# Processing Record 147 | maputo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=maputo
# Processing Record 148 | darhan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=darhan
# Processing Record 149 | flin flon
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=flin%20flon
# Processing Record 150 | preobrazheniye
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=preobrazheniye
# Processing Record 151 | margate
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=margate
# Processing Record 152 | san patricio
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=san%20patricio
# Processing Record 153 | upernavik
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=upernavik
# Processing Record 154 | port lincoln
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=port%20lincoln
# Processing Record 155 | norman wells
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=norman%20wells
# Processing Record 156 | kaitangata
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kaitangata
# Processing Record 157 | halifax
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=halifax
# Processing Record 158 | alofi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=alofi
# Processing Record 159 | monrovia
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=monrovia
# Processing Record 160 | uglegorsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=uglegorsk
# Processing Record 161 | san juan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=san%20juan
# Processing Record 162 | tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tuktoyaktuk
# Processing Record 163 | iquique
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=iquique
# Processing Record 164 | ottawa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ottawa
# Processing Record 165 | tiksi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tiksi
# Processing Record 166 | sechura
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sechura
# City not found. Skipping
# Processing Record 167 | pacific grove
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pacific%20grove
# Processing Record 168 | alice springs
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=alice%20springs
# Processing Record 169 | chokurdakh
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=chokurdakh
# Processing Record 170 | posse
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=posse
# Processing Record 171 | mahebourg
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mahebourg
# Processing Record 172 | redmond
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=redmond
# Processing Record 173 | faya
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=faya
# City not found. Skipping
# Processing Record 174 | tia mare
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tia%20mare
# Processing Record 175 | kota kinabalu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kota%20kinabalu
# Processing Record 176 | bograd
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bograd
# Processing Record 177 | katsuura
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=katsuura
# Processing Record 178 | ongandjera
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ongandjera
# Processing Record 179 | nhamunda
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nhamunda
# Processing Record 180 | lazaro cardenas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=lazaro%20cardenas
# Processing Record 181 | togur
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=togur
# Processing Record 182 | acapulco
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=acapulco
# Processing Record 183 | emmett
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=emmett
# Processing Record 184 | constitucion
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=constitucion
# Processing Record 185 | grand-santi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=grand-santi
# Processing Record 186 | henties bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=henties%20bay
# Processing Record 187 | itapetinga
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=itapetinga
# Processing Record 188 | balikpapan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=balikpapan
# Processing Record 189 | kodiak
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kodiak
# Processing Record 190 | katima mulilo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=katima%20mulilo
# Processing Record 191 | saint-louis
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=saint-louis
# City not found. Skipping
# Processing Record 192 | igaracu do tiete
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=igaracu%20do%20tiete
# Processing Record 193 | vardo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=vardo
# Processing Record 194 | severo-kurilsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=severo-kurilsk
# Processing Record 195 | san carlos del zulia
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=san%20carlos%20del%20zulia
# Processing Record 196 | ngora
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ngora
# Processing Record 197 | shingu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=shingu
# Processing Record 198 | mazatlan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mazatlan
# Processing Record 199 | clyde river
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=clyde%20river
# Processing Record 200 | bethanien
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bethanien
# Processing Record 201 | ust-tsilma
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ust-tsilma
# Processing Record 202 | iisalmi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=iisalmi
# Processing Record 203 | ponta do sol
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ponta%20do%20sol
# Processing Record 204 | touros
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=touros
# City not found. Skipping
# Processing Record 205 | broome
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=broome
# Processing Record 206 | carnarvon
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=carnarvon
# Processing Record 207 | lompoc
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=lompoc
# Processing Record 208 | castro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=castro
# Processing Record 209 | kyzyl-suu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kyzyl-suu
# Processing Record 210 | half moon bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=half%20moon%20bay
# Processing Record 211 | paamiut
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=paamiut
# Processing Record 212 | skibbereen
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=skibbereen
# Processing Record 213 | saint-philippe
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=saint-philippe
# Processing Record 214 | mbarara
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mbarara
# City not found. Skipping
# Processing Record 215 | srednekolymsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=srednekolymsk
# Processing Record 216 | petropavlovka
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=petropavlovka
# Processing Record 217 | brtnice
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=brtnice
# Processing Record 218 | segovia
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=segovia
# Processing Record 219 | feira de santana
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=feira%20de%20santana
# Processing Record 220 | batticaloa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=batticaloa
# Processing Record 221 | bilibino
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bilibino
# City not found. Skipping
# Processing Record 222 | barinas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=barinas
# City not found. Skipping
# Processing Record 223 | eyrarbakki
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=eyrarbakki
# Processing Record 224 | atherton
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=atherton
# Processing Record 225 | kurchum
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kurchum
# Processing Record 226 | sao joao da barra
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sao%20joao%20da%20barra
# Processing Record 227 | ahipara
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ahipara
# Processing Record 228 | una
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=una
# Processing Record 229 | launceston
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=launceston
# Processing Record 230 | jollyville
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=jollyville
# Processing Record 231 | grand gaube
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=grand%20gaube
# Processing Record 232 | buala
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=buala
# Processing Record 233 | port hardy
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=port%20hardy
# Processing Record 234 | luderitz
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=luderitz
# Processing Record 235 | canon city
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=canon%20city
# Processing Record 236 | afua
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=afua
# Processing Record 237 | viana
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=viana
# Processing Record 238 | mount isa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mount%20isa
# Processing Record 239 | adrar
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=adrar
# Processing Record 240 | cao bang
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cao%20bang
# Processing Record 241 | veraval
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=veraval
# Processing Record 242 | bambanglipuro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bambanglipuro
# Processing Record 243 | sao filipe
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sao%20filipe
# Processing Record 244 | chirongui
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=chirongui
# Processing Record 245 | kandrian
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kandrian
# City not found. Skipping
# Processing Record 246 | fort morgan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=fort%20morgan
# Processing Record 247 | cape town
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cape%20town
# Processing Record 248 | correntina
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=correntina
# Processing Record 249 | burns lake
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=burns%20lake
# Processing Record 250 | hambantota
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hambantota
# Processing Record 251 | macomb
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=macomb
# Processing Record 252 | carballo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=carballo
# Processing Record 253 | meulaboh
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=meulaboh
# Processing Record 254 | nouadhibou
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nouadhibou
# Processing Record 255 | caraubas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=caraubas
# Processing Record 256 | erzin
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=erzin
# Processing Record 257 | bandarbeyla
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bandarbeyla
# Processing Record 258 | kutum
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kutum
# City not found. Skipping
# Processing Record 259 | mutare
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mutare
# Processing Record 260 | tyukalinsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tyukalinsk
# Processing Record 261 | tautira
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tautira
# Processing Record 262 | porbandar
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=porbandar
# Processing Record 263 | hamilton
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hamilton
# Processing Record 264 | camacupa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=camacupa
# Processing Record 265 | yerbogachen
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=yerbogachen
# Processing Record 266 | banepa
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=banepa
# Processing Record 267 | baykit
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=baykit
# Processing Record 268 | santa maria da vitoria
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=santa%20maria%20da%20vitoria
# City not found. Skipping
# Processing Record 269 | quatre cocos
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=quatre%20cocos
# Processing Record 270 | diego de almagro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=diego%20de%20almagro
# Processing Record 271 | mwinilunga
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mwinilunga
# Processing Record 272 | ponta delgada
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ponta%20delgada
# Processing Record 273 | ugoofaaru
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ugoofaaru
# Processing Record 274 | carutapera
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=carutapera
# Processing Record 275 | whyalla
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=whyalla
# Processing Record 276 | walvis bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=walvis%20bay
# Processing Record 277 | avera
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=avera
# Processing Record 278 | coihaique
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=coihaique
# Processing Record 279 | salalah
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=salalah
# Processing Record 280 | vila velha
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=vila%20velha
# Processing Record 281 | cockburn town
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cockburn%20town
# Processing Record 282 | zhezkazgan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=zhezkazgan
# Processing Record 283 | luanda
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=luanda
# Processing Record 284 | makat
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=makat
# Processing Record 285 | bubaque
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bubaque
# Processing Record 286 | coquimbo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=coquimbo
# Processing Record 287 | maceio
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=maceio
# Processing Record 288 | andros town
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=andros%20town
# Processing Record 289 | sena madureira
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sena%20madureira
# Processing Record 290 | homa bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=homa%20bay
# City not found. Skipping
# City not found. Skipping
# Processing Record 291 | esperance
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=esperance
# Processing Record 292 | ketchikan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ketchikan
# Processing Record 293 | kieta
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kieta
# Processing Record 294 | rorvik
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rorvik
# Processing Record 295 | nome
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nome
# Processing Record 296 | thompson
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=thompson
# Processing Record 297 | marsa matruh
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=marsa%20matruh
# Processing Record 298 | gizo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=gizo
# Processing Record 299 | torbay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=torbay
# City not found. Skipping
# Processing Record 300 | cherskiy
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cherskiy
# City not found. Skipping
# Processing Record 301 | samarai
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=samarai
# Processing Record 302 | hasaki
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hasaki
# Processing Record 303 | padang
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=padang
# Processing Record 304 | qasigiannguit
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=qasigiannguit
# Processing Record 305 | prince rupert
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=prince%20rupert
# Processing Record 306 | petropavlovsk-kamchatskiy
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=petropavlovsk-kamchatskiy
# Processing Record 307 | atambua
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=atambua
# Processing Record 308 | beringovskiy
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=beringovskiy
# Processing Record 309 | porto novo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=porto%20novo
# Processing Record 310 | taunggyi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=taunggyi
# City not found. Skipping
# Processing Record 311 | tsaratanana
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tsaratanana
# Processing Record 312 | geraldton
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=geraldton
# Processing Record 313 | pangkalanbuun
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pangkalanbuun
# Processing Record 314 | kaili
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kaili
# Processing Record 315 | payakumbuh
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=payakumbuh
# Processing Record 316 | tuatapere
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tuatapere
# Processing Record 317 | fuyang
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=fuyang
# Processing Record 318 | woonsocket
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=woonsocket
# City not found. Skipping
# Processing Record 319 | havelock
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=havelock
# City not found. Skipping
# Processing Record 320 | maxixe
# ...
# City not found. Skipping
# Processing Record 454 | felanitx
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=felanitx
# Processing Record 455 | alyangula
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=alyangula
# Processing Record 456 | guerrero negro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=guerrero%20negro
# Processing Record 457 | macas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=macas
# Processing Record 458 | listowel
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=listowel
# Processing Record 459 | canora
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=canora
# Processing Record 460 | inhambane
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=inhambane
# Processing Record 461 | pimenteiras
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pimenteiras
# City not found. Skipping
# Processing Record 462 | zyryanka
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=zyryanka
# Processing Record 463 | luoyang
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=luoyang
# Processing Record 464 | belmonte
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=belmonte
# Processing Record 465 | dafeng
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dafeng
# Processing Record 466 | katangli
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=katangli
# Processing Record 467 | sorland
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sorland
# Processing Record 468 | murgab
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=murgab
# Processing Record 469 | rundu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rundu
# Processing Record 470 | sunderland
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sunderland
# Processing Record 471 | pasighat
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pasighat
# Processing Record 472 | viedma
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=viedma
# Processing Record 473 | angola
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=angola
# Processing Record 474 | adre
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=adre
# Processing Record 475 | erenhot
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=erenhot
# Processing Record 476 | ferkessedougou
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ferkessedougou
# Processing Record 477 | san vicente
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=san%20vicente
# Processing Record 478 | san quintin
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=san%20quintin
# City not found. Skipping
# Processing Record 479 | salinas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=salinas
# Processing Record 480 | nutley
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nutley
# Processing Record 481 | ginda
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ginda
# Processing Record 482 | tilichiki
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tilichiki
# Processing Record 483 | kumphawapi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kumphawapi
# Processing Record 484 | port-gentil
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=port-gentil
# Processing Record 485 | sri aman
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sri%20aman
# Processing Record 486 | nanakuli
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nanakuli
# Processing Record 487 | uhlove
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=uhlove
# City not found. Skipping
# Processing Record 488 | celestun
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=celestun
# City not found. Skipping
# City not found. Skipping
# Processing Record 489 | inongo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=inongo
# Processing Record 490 | taywarah
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=taywarah
# Processing Record 491 | bougouni
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bougouni
# Processing Record 492 | plettenberg bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=plettenberg%20bay
# Processing Record 493 | malumfashi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=malumfashi
# Processing Record 494 | saldanha
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=saldanha
# Processing Record 495 | gobabis
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=gobabis
# Processing Record 496 | moche
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=moche
# Processing Record 497 | teya
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=teya
# Processing Record 498 | sturgeon bay
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sturgeon%20bay
# Processing Record 499 | san cristobal
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=san%20cristobal
# Processing Record 500 | bima
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bima
# Processing Record 501 | shieli
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=shieli
# Processing Record 502 | kirovsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kirovsk
# Processing Record 503 | tucurui
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=tucurui
# Processing Record 504 | bafq
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bafq
# City not found. Skipping
# Processing Record 505 | pitimbu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pitimbu
# Processing Record 506 | svetlogorsk
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=svetlogorsk
# Processing Record 507 | hohhot
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=hohhot
# City not found. Skipping
# Processing Record 508 | sioux lookout
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sioux%20lookout
# Processing Record 509 | treinta y tres
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=treinta%20y%20tres
# City not found. Skipping
# Processing Record 510 | rio gallegos
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rio%20gallegos
# Processing Record 511 | noumea
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=noumea
# Processing Record 512 | kyabram
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kyabram
# City not found. Skipping
# Processing Record 513 | kollam
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kollam
# Processing Record 514 | ishigaki
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ishigaki
# City not found. Skipping
# Processing Record 515 | miles city
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=miles%20city
# Processing Record 516 | aragarcas
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=aragarcas
# Processing Record 517 | bastia
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bastia
# Processing Record 518 | kortkeros
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kortkeros
# Processing Record 519 | kalmunai
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kalmunai
# Processing Record 520 | sitka
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sitka
# Processing Record 521 | yunyang
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=yunyang
# Processing Record 522 | soe
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=soe
# Processing Record 523 | pevek
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=pevek
# Processing Record 524 | china
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=china
# Processing Record 525 | cayenne
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=cayenne
# Processing Record 526 | teknaf
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=teknaf
# Processing Record 527 | narsaq
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=narsaq
# Processing Record 528 | dunmore town
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dunmore%20town
# Processing Record 529 | fairbanks
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=fairbanks
# Processing Record 530 | linkou
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=linkou
# Processing Record 531 | kukes
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kukes
# Processing Record 532 | mountain home
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=mountain%20home
# Processing Record 533 | kharan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kharan
# Processing Record 534 | yuryuzan
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=yuryuzan
# Processing Record 535 | kununurra
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kununurra
# Processing Record 536 | thinadhoo
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=thinadhoo
# Processing Record 537 | dudinka
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=dudinka
# Processing Record 538 | vila do maio
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=vila%20do%20maio
# Processing Record 539 | whitecourt
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=whitecourt
# Processing Record 540 | rio grande
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rio%20grande
# Processing Record 541 | novo cruzeiro
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=novo%20cruzeiro
# Processing Record 542 | marawi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=marawi
# Processing Record 543 | iwaki
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=iwaki
# Processing Record 544 | panorama
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=panorama
# Processing Record 545 | jiupu
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=jiupu
# City not found. Skipping
# Processing Record 546 | rovaniemi
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rovaniemi
# Processing Record 547 | sorong
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sorong
# Processing Record 548 | inirida
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=inirida
# Processing Record 549 | qaqortoq
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=qaqortoq
# Processing Record 550 | rampura
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=rampura
# Processing Record 551 | norden
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=norden
# Processing Record 552 | kasongo-lunda
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=kasongo-lunda
# City not found. Skipping
# Processing Record 553 | bucerias
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bucerias
# Processing Record 554 | parabel
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=parabel
# Processing Record 555 | nizhyn
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=nizhyn
# Processing Record 556 | bahia de caraquez
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=bahia%20de%20caraquez
# Processing Record 557 | ipanema
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=ipanema
# Processing Record 558 | wilmington
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=wilmington
# Processing Record 559 | sur
# https://api.openweathermap.org/data/2.5/weather?APPID=7d30e927abdcc87644d6f9c6359b8026&units=imperial&q=sur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_df.to_csv('weather_data.csv')
data_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1      bluff         0.0      AU  2019-01-13      69.0 -23.58  149.07
# 2   victoria        75.0      BN  2019-01-13      88.0   5.28  115.24
# 3  wattegama        24.0      LK  2019-01-13      97.0   7.35   80.68
# 4      vaini         0.0      IN  2019-01-13      79.0  15.34   74.49
# 5     souris        75.0      CA  2019-01-13      72.0  46.36  -62.25
#
#    Max_temp  Wind_speed
# 1     72.15       10.56
# 2     78.80        3.36
# 3     67.51        2.84
# 4     58.78        2.62
# 5     10.40        6.93

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure()
plt.scatter(data_df['Lat'],data_df['Max_temp'])
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.title(f"City Latitude vs Max Temp ({data_df.iloc[0]['Date']})")
plt.savefig('LatvsTemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure()
plt.scatter(data_df['Lat'],data_df['Humidity'])
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"City Latitude vs Humidity ({data_df.iloc[0]['Date']})")
plt.savefig('LatvsTemp.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure()
plt.scatter(data_df['Lat'],data_df['Cloudiness'])
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"City Latitude vs Cloudiness ({data_df.iloc[0]['Date']})")
plt.savefig('LatvsTemp.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure()
plt.scatter(data_df['Lat'],data_df['Wind_speed'])
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"City Latitude vs Wind Speed ({data_df.iloc[0]['Date']})")
plt.savefig('LatvsTemp.png')
